# %% [markdown]
# #Regresi Linier Dengan OLS

# %% [markdown]
# **Pembuka**
#
# Assalamu'alaikum warahmatullahi wabarakatuh. Puji syukur kehadirat Allah Subhana Wata'ala atas limpahan
# Rahmat dan HidayahNya kepada kita semua. Sholawat serta salam senantiasa tercurah limpahkan kepada
# baginda Muhammad Rasulullah Salallahualaihiwassalam.
#
# Halo para Pejuang Data. Selamat berjumpa di pertemuan ketiga Program Training Algoritma Machine
# Learning Kelas Mahir.
#
# Pada pertemuan ini kamu akan belajar:
#
# - Model Regresi Linear Sederhana
# - Ordinary Least Mean Square
# - Contoh Perhitungan Manual Regresi Linear dengan OLS
# - Regresi Linear Python From Scratch
#
# **Model Regresi Linear Sederhana**
#
# Regresi Linear adalah metode untuk mendefinisikan hubungan linear antara variabel dependen Y dan variabel
# independen X. Secara sederhana dapat dituliskan dalam formula berikut:
#
#   $𝑌_𝑖 = 𝑏_0 + 𝑏_1 𝑋𝑖 + 𝜖_𝑖$
#
# Yang mana 𝑌𝑖 adalah variabel dependen 𝑋𝑖, 𝜖 adalah variabel independen, adalah kesalahan acak,𝑏0 disebut
# sebagai intercept 𝑏1 dan disebut sebagai koefisien regresi yang dapat diestimasi berdasarkan data 𝑌𝑖 dan 𝑋𝑖
# yang diberikan. Koefisien juga biasa disebut sebagai bias. Tujuan utama dari model ini adalah untuk
# mengambarkan garis linear dengan kesesuaian terbaik(best fit) antara X dan Y yang mengestimasi hubungan
# antara X dan Y.
#
#
# Lalu bagaimana untuk mengestimasi koefisien tersebut? Salah satu pendekatan yang dapat dilakukan adalah
# mengunakan metode Ordinary Least Mean Square Method . Pada python notebook ini, kita akan
# mengimplementasikan metode Ordinary Least Mean Square Method.
#
# **Ordinary Least Mean Square**
#
# Sebelumnya kita telah membahas tentang estimasi hubungan antara X dan Y pada sebuah garis. Misalnya, kita
# sediakan input dan output sampel, kemudian kita memplot titik titik data ini pada grafik 2 dimensi, maka akan
# dihasilkan grafik seperti di bawah ini:
#
# ![image.png](data:image/png;base64,...)
#
# Garis merah pada grafik adalah hubungan sesungguhnya yang ingin disetimasi. Kita berusaha untuk
# meminimalkan kesalahan model yang kita bangun. Garis ini adalah garis yang paling tepat menggambarkan
# hubungan antara data X dan Y dengan melewati sebagian besar titik data dan memiliki kesalahan yang paling
# minimal. Kesalahan ini berupa jarak titik data ke garis estimasi model ini. Secara konseptual kesalahan ini
# diilustrasikan pada gambar di bawah ini.
#
# ![image.png](data:image/png;base64,...)
#
# Dan kesalahan total model linier adalah jumlah kesalahan dari setiap titiknya, yaitu :
#
# $\sum \limits_{i=1}^{n} {𝜖_i}^2$
#
# 𝜖𝑖 = Jarak antara garis ke titik data ke-i
#
# n = Jumlah total titik data
#
# Formula di atas diperoleh dari:
#
# $ y_i = b_0 +b_1.x_i + 𝜖_i$
#
# $𝜖_i = y_i -b_0 -b_1.x_i$
#
# $\sum \limits_{i=1}^{n} 𝜖_i^2 = \sum \limits_{i=1}^{n} ( y_i - b_0 - b_1.x_i)^2$
#
# Pada baris terakhir persamaan di atas kita mengkuadratkan kesalahan yang berupa jarak antara garis
# estimasi dengan titik data. Kita dapat mengkuadratkan masing-masing jarak karena terdapat beberapa titik di
# atas garis dan beberapa di bawahnya. Kemudian, untuk memperoleh model terbaik jarak tersebut dapat kita
# minimumkan. Misal $\sum \limits_{i=1}^{n} {𝜖_i}^2$ = J
#
# Ide Dasar Metode OLS: Nilai minimum dari fungsi kesalahan  $\sum \limits_{i=1}^{n} {𝜖_i}^2$
# terjadi saat turunan pertama
# terhadap koefisien b0 dan b1 sama dengan b0. Ini merujuk pada konsep dasar turunan fungsi dalam
# kalkulus yaitu nilai minimum suatu fungsi terjadi saat turunan pertamanya sama dengan 0.
#
# Konsep ini kemudian diperluas menjadi metode Gradient Descent.
#
#
# Mencari nilai minimum untuk $𝑏_0$
#
#
#
# $ J = \sum_{i=1}^{n}(y_{i}-b_{0}-b_{1}\cdot x_{i})^2 $
#
#
# $ \frac{\partial J}{\partial b_{0}}=-2\sum_{i=1}^{n}(y_{i}-b_{0}-b_{1}\cdot x_{i})^{(2-1)}\cdot(-1) $
#
#
# $\frac{\partial J}{\partial b_{0}}=-2\sum_{i=1}^{n}(y_{i}-b_{0}-b_{1}\cdot x_{i})$
#
#
# $\frac{\partial J}{\partial b_{0}}=0$
#
#
# $\sum_{i=1}^{n}(y_{i}-\hat{b_{0}}-\hat{b_{1}}\cdot x_{i}) = 0$
#
#
# $\sum_{i=1}^{n}y_{i}-n\hat{b_{0}}-\hat{b_{1}}\sum_{i=1}^{n}x_{i}=0$
#
#
# $n\hat{b_{0}}=\sum_{i=1}^{n}y_{i}-\hat{b_{1}}\sum_{i=1}^{n}x_{i}$
#
#
# $\hat{b_{0}}=\frac{\sum_{i=1}^{n}y_{i}-\hat{b_{1}}\sum_{i=1}^{n}x_{i}}{n}$
#
#
# $\hat{b_{0}}=\bar{y}-\hat{b_{1}\bar{x}}$
#
#
# diperoleh formula untuk $b_{0}$ adalah
#
#
# $\hat{b_{0}}=\bar{y}-\hat{b_{1}}\bar{x}$
#
#
# $J = \sum \limits_{i=1}^n (y_i - b_0 - b_1.x_-i)^2$
#
#
#
# $\frac{\partial J}{\partial b_0}= 2\sum \limits_{i=1}^n (y_i - b_0 - b_1.x_-i)^(2-1) .(-x_1)$
#
#
# $\frac{\partial J}{\partial b_0}= -2\sum \limits_{i=1}^n (y_i - b_0 - b_1.x_-i)^(2-1) $
#
#
# $\frac{\partial J}{\partial b_0} = 0$
#
#
# $\sum \limits_{i=1}^n x_i.y_i - \hat{b_0}\sum \limits_{i=1}^nx_i - \hat{b_1}\sum \limits_{i=1}^n x^2_i = 0$
#
# $\sum \limits_{i=1}^n x_i.y_i - (\frac{\sum \limits_{i=1}^ny_i-\hat{b_1} \sum \limits_{i=1}^n x_i}{n}) \sum \limits_{i=1}^n x_i - \hat{b_1} \sum \limits_{i=1}^n\hat{x^2_i} = 0$
#
#
# $\sum \limits_{i=1}^nx_i.y_i - \frac{\sum \limits_{i=1}^nx_i \sum \limits_{i=1}^ny_i}{n} + \hat{b_1}\frac{(\sum \limits_{i=1}^n x_i)^2}{n}-\hat{b_1}\sum \limits_{i=1}^n x^2_i = 0$
#
#
# $\hat{b_1} (\frac{(\sum \limits_{i=1}^n x_i)^2}{n}  - \sum \limits_{i=1}^nx^2_i) = \frac {\sum \limits_{i=1}^n x_i \sum \limits_{i=1}^n y_i}{n}- \sum \limits_{i=1}^nx_i.y_i$
#
#
# $\hat{b_i} = \frac{\sum \limits_{i=1}^{n}  x_i y_i - \frac{\sum \limits_{i=1}^{n} x_i\sum \limits_{i=1}^{n}  y_i}{n}}{ \sum \limits_{i=1}^{n} x^2_i - \frac {(\sum \limits_{i=1}^{n} x_i)^2}{n}}$
#
#
#
#
#
#
#
#
#
#
#
#
# Sehingga diperoleh formula untuk $𝑏_1$ adalah
#
# $\hat{b_i} = \frac{\sum \limits_{i=1}^{n}  x_i y_i - \frac{\sum \limits_{i=1}^{n} x_i\sum \limits_{i=1}^{n}  y_i}{n}}{ \sum \limits_{i=1}^{n} x^2_i - \frac {(\sum \limits_{i=1}^{n} x_i)^2}{n}}$
#
#
# Persamaan terakhir bisa ditulis ulang untuk kemudahan pemrograman sebagai berikut:
#
#  $\hat{b_1} = \frac {\sum \limits_{i=1}^{n} (x_i - \bar{x})(y_i - \bar{y})}{\sum \limits_{i=1}^{n} (x_i - \bar{x})^2}$
#
#  Setelah mendapatkan keduanya, kita dapat mulai melakukan implementasi pada python.
#
# **Contoh Perhitungan Manual Regresi Linear dengan OLS**
#
# Diketahui data X dan Y adalah sebagai berikut(Y=2X-1):
#
# $\left( \begin{matrix}
#   X & Y \\
#   1 & 1 \\
#   3 & 5 \\
#   5 & 9 \\
#   6 & 11\\
#   7 & 13 \\
#   8 & 15 \\
# \end{matrix} \right) $
#
#
#
# Berikut adalah proses menghitung model Regresi Linear dari data di atas:
#
#
# **1. Menghitung rata-rata X dan Y**
#
# $n = 6$
#
# $\hat{x} = \frac {1+3=5+6+7+8}{6} = 5$
#
#
# $\hat{y} = \frac {1+5+9+11+13+15}{6} = 9$
#
#
#
#
#
# **2. Menghitung** $b_1$
#
# $\hat{b_1} = \frac {\sum \limits_{i=1}^{n} (x_i - \bar{x})(y_i - \bar{y})}{\sum \limits_{i=1}^{n} (x_i - \bar{x})^2}$
#
# $\hat{b_1} = \frac {([1-5][1-9]+[3-5][5-9]+[5-5][9-9]+[6-5][11-9]+[7-5][13-9]+[8-5][13-7])}{([1-5]^2 + [3-5]^2 + [5-5]^2 +[6-5]^2 +[7-5]^2 +[8-5]^2)}$
#
# $\hat{b_1} =\frac{32+8+0+2+8+18}{16+4+0+1+4+9}$
#
# $\hat{b_1} = 2$
#
# **2. Menghitung $b_0*$*
#
#  $\hat{b_0} = \bar{y} - \hat{b_1}\bar{x}$
#
# $\hat{b_0} = 9- (2) x 5 $
#
# $\hat{b_0} = -1$
#
# **3. Menyusun Persamaan Regresi Linear**
#
# $Y = \hat{b_0} + \hat{b_1} x$
#
# $Y = -1 + 2x$
#
# **Regresi Linear Python From Scratch**
#
# **Membangun Model Regresi Linear**
#
# Pertama, import library python yang dibutuhkan yaitu:-
#
# - Numpy
# - Pandas
# - Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# Untuk memahami konsep, kita akan menggunakan data X dan Y seperti yang kita tunjukkan pada proses
# penghitungan manual.

# %%
X_train=np.array([1, 3, 5, 6, 7, 8])
y_train=np.array([1, 5, 9, 11, 13, 15])

# %%
# Proses Training Model
# Menghitung rata-rata inputs and outputs
x_rata2 = np.mean(X_train)
print("Rata-rata X:", x_rata2)
y_rata2 = np.mean(y_train)
print("Rata-rata Y:", y_rata2)
# Jumlah data
n = len(X_train)
print("Jumlah data(n):", y_rata2)
# Menuliskan formula untuk menghitung beta 0 dan beta 1
A = 0
B = 0
for i in range(n):
 a = (X_train[i] - x_rata2) * (y_train[i] - y_rata2)
 print("(",X_train[i], "-", x_rata2, ")", "*", "(", y_train[i], "-", y_rata2, ") =", a )
 A += a
 b = (X_train[i] - x_rata2) ** 2
 print("(", X_train[i], "-", x_rata2, ")", "^2", " =", b )
 B += b

print("Pembilang =", A)
print("Penyebut =", B)
# Menampilkan Koefisien Regresi Linear
b_1 = A / B
print("b_1 =", b_1)
b_0 = y_rata2 - (b_1 * x_rata2)
print("b_0 =", b_0)
# Out:
# Rata-rata X: 5.0
# Rata-rata Y: 9.0
# Jumlah data(n): 9.0
# ( 1 - 5.0 ) * ( 1 - 9.0 ) = 32.0
# ( 1 - 5.0 ) ^2  = 16.0
# ( 3 - 5.0 ) * ( 5 - 9.0 ) = 8.0
# ( 3 - 5.0 ) ^2  = 4.0
# ( 5 - 5.0 ) * ( 9 - 9.0 ) = 0.0
# ( 5 - 5.0 ) ^2  = 0.0
# ( 6 - 5.0 ) * ( 11 - 9.0 ) = 2.0
# ( 6 - 5.0 ) ^2  = 1.0
# ( 7 - 5.0 ) * ( 13 - 9.0 ) = 8.0
# ( 7 - 5.0 ) ^2  = 4.0
# ( 8 - 5.0 ) * ( 15 - 9.0 ) = 18.0
# ( 8 - 5.0 ) ^2  = 9.0
# Pembilang = 68.0
# Penyebut = 34.0
# b_1 = 2.0
# b_0 = -1.0

# %%
# Plot Nilai Data
x_max = np.max(X_train)
x_min = np.min(X_train)
# Garis Regresi
x = np.linspace(x_min, x_max, 1000)
y = b_0 + b_1 * x
# Plott Garis Regresi
plt.plot(x, y, color='red', label='Regresi Linear')
# Plot Titik Data
plt.scatter(X_train, y_train, color='blue', label='Data')
# Label sumbu
plt.xlabel('X')
# Label sumbu y
plt.ylabel('Y')
# Menampilkan Legenda
plt.legend()
# Menampilkan Gambar Hasil Plot
plt.show()

# %% [markdown]
# **Implementasi Model Regresi Linear Pada Data Real**
#
# Kita akan menggunakan dataset yang berisi ukuran kepala dan berat organ otak.

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/jokoeliyanto/Channel-Hobi-Data/main/Model%20Machine%20Learning%20dari%20Dasar(From%20Scratch)%20Python/Dataset/dataset_regresi_linear.csv')
# Melihat ukuran dataset
print(dataset.shape)
# Menampilkan 5 data teratas
dataset.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
# Definisikan Variabel Input(X) dan Output(Y)
X = dataset['Head Size(cm^3)'].values.reshape(-1,1)
Y = dataset['Brain Weight(grams)'].values.reshape(-1,1)

# %%
# Membagi data menjadi data training dan data testing
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
# Proses Training Model
# Menghitung rata-rata inputs and outputs
x_rata2 = np.mean(X_train)
y_rata2 = np.mean(y_train)
# Jumlah data
n = len(X_train)
# Menuliskan formula untuk menghitung beta 0 dan beta 1
A = 0
B = 0
for i in range(n):
   A += (X_train[i] - x_rata2) * (y_train[i] - y_rata2)
   B += (X_train[i] - x_rata2) ** 2
b_1 = A / B
b_0 = y_rata2 - (b_1 * x_rata2)
# Menampilkan Koefisien Regresi Linear
print(b_0, b_1)
# Out:
# [334.26127335] [0.26106902]

# %% [markdown]
# Dalam notasi matematika, hasil ini dapat ditulis sebagai berikut:
#
#
# Brain weights = 334.26127335 + 0.26106902 * Head size
#
#
# Sekarang kita memiliki model linier. Mari kita plot secara grafis.

# %%
# Plot Nilai Data
x_max = np.max(X) + 100
x_min = np.min(X) - 100
# Garis Regresi
x = np.linspace(x_min, x_max, 1000)
y = b_0 + b_1 * x
# Plott Garis Regresi
plt.plot(x, y, color='red', label='Regresi Linear')
# Plot Titik Data
plt.scatter(X, Y, color='blue', label='Data')
# Label sumbu
plt.xlabel('Head Size (cm^3)')
# Label sumbu y
plt.ylabel('Brain Weight (grams)')
# Menampilkan Legenda
plt.legend()
# Menampilkan Gambar Hasil Plot
plt.show()

# %% [markdown]
# ###Evaluasi Model

# %% [markdown]
# Kita perlu mengukur tingkat ketepatan(akurasi) model yang telah diperoleh. Terdapat banyak metode untuk
# melakukan hal ini, namun pada artikel ini kita memilih menggunakan **Root Mean Square Error dan Koefisien
# Determinasi** ($R^2$ Skor)
#
# $RMSE = \sqrt{\frac {1}{n}\sum \limits_{i=1}^{n}(y_i - \hat{y_i})^2}$
#
# $\hat{y_i}$
#  adalah nilai hasil prediksi ke-i. Berikut adalah penulisan kode untuk RMSE

# %%
rmse = 0
for i in range(len(X_test)):
 y_pred= b_0 + b_1* X_test[i]
 rmse += (y_test[i] - y_pred) ** 2
 
rmse = np.sqrt(rmse/n)
print(rmse)
# Out:
# [36.34269155]

# %% [markdown]
# Selanjutnya, mari kita hitung nilai skor untuk mengukur tingkat akurasi dari model linear yang diperoleh,
# secara matematis dituliskan sebagai berikut:
#
# $R^2 = 1 - \frac {SSE}{SST} = 1 - \frac {\sum (\hat{y_i - \bar{y}})}{\sum (y_i - \bar{y})}$
#
# SSE adalah jumlah kuadrat galat sedangkan SST jumlah kuadrat total.
#
#  $R^2$ skor biasanya memiliki nilai antara 0 hingga 1. Nilai ini juga bisa bernilai negatif jika model regresi benarbenar salah. Di bawah ini adalah kode pemrograman untuk menghitung $R^2$ skor

# %%
SST = 0
SSE = 0
y_pred= b_0 + b_1*X_test
y_rata2 = np.mean(y_test)
for i in range(len(X_test)) :
 SST += (y_test[i] - y_rata2) ** 2
 SSE += (y_test[i] - y_pred[i]) **2
score = 1- (SSE/SST)
print("Koefisien Determinasi:", score)
# Out:
# Koefisien Determinasi: [0.63763642]

# %% [markdown]
# ##IMPLEMENTASI

# %%
data = pd.read_csv('https://raw.githubusercontent.com/sintia123445/possum/main/possum%20(1).csv' )
print(data.shape)
data.head()
# Out:
# (104, 8)
#    site  pop sex  age  head_l  skull_w  total_l  tail_l
# 0     1  Vic   m  8.0    94.1     60.4     89.0    36.0
# 1     1  Vic   f  6.0    92.5     57.6     91.5    36.5
# 2     1  Vic   f  6.0    94.0     60.0     95.5    39.0
# 3     1  Vic   f  6.0    93.2     57.1     92.0    38.0
# 4     1  Vic   f  2.0    91.5     56.3     85.5    36.0

# %%
# Definisikan Variabel Input(X) dan Output(Y)
X = data['skull_w'].values.reshape(-1,1)
Y = data['age'].values.reshape(-1,1)

# %%
# Membagi data menjadi data training dan data testing
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
# Proses Training Model
# Menghitung rata-rata inputs and outputs
x_rata2 = np.mean(X_train)
y_rata2 = np.mean(y_train)
# Jumlah data
n = len(X_train)
# Menuliskan formula untuk menghitung beta 0 dan beta 1
A = 0
B = 0
for i in range(n):
   A += (X_train[i] - x_rata2) * (y_train[i] - y_rata2)
   B += (X_train[i] - x_rata2) ** 2
b_1 = A / B
b_0 = y_rata2 - (b_1 * x_rata2)
# Menampilkan Koefisien Regresi Linear
print(b_0, b_1)
# Out:
# [-9.05024852] [0.22661522]

# %%
# Plot Nilai Data
x_max = np.max(X) + 100
x_min = np.min(X) - 100
# Garis Regresi
x = np.linspace(x_min, x_max, 1000)
y = b_0 + b_1 * x
# Plott Garis Regresi
plt.plot(x, y, color='blue', label='Regresi Linear')
# Plot Titik Data
plt.scatter(X, Y, color='green', label='Data')
# Label sumbu
plt.xlabel('skull_w')
# Label sumbu y
plt.ylabel('age')
# Menampilkan Legenda
plt.legend()
# Menampilkan Gambar Hasil Plot
plt.show()

# %%
rmse = 0
for i in range(len(X_test)):
 y_pred= b_0 + b_1* X_test[i]
 rmse += (y_test[i] - y_pred) ** 2
 
rmse = np.sqrt(rmse/n)
print(rmse)
# Out:
# [nan]

# %%
SST = 0
SSE = 0
y_pred= b_0 + b_1*X_test
y_rata2 = np.mean(y_test)
for i in range(len(X_test)) :
 SST += (y_test[i] - y_rata2) ** 2
 SSE += (y_test[i] - y_pred[i]) **2
score = 1- (SSE/SST)
print("Koefisien Determinasi:", score)
# Out:
# Koefisien Determinasi: [nan]
